# %%
import pytse_client as tse
import pandas as pd

# %%
tickers = tse.download(symbols="all", write_to_csv=True)

# %%
type(tickers)
# Out:
# dict

# %%
tickers

# %%
import pandas as pd
import sqlite3

df = pd.read_csv('tickers_data/آبین.csv')

# %%
df
# Out:
#            date     open     high      low  adjClose        value   volume  \
# 0    2017-02-14   1000.0   1000.0   1000.0    1000.0        10000       10
# 1    2018-05-21   2000.0   2000.0   2000.0    2000.0   2725398000  1362699
# 2    2018-05-23   2000.0   2000.0   1950.0    1996.0    842461700   422047
# 3    2018-05-26   1995.0   1995.0   1601.0    1966.0     75575920    41560
# 4    2018-05-28   1890.0   1890.0   1890.0    1929.0    228225060   120754
# ..          ...      ...      ...      ...       ...          ...      ...
# 352  2020-05-19  41215.0  41215.0  41215.0   41215.0  34845427825   845455
# 353  2020-05-20  42451.0  42451.0  42451.0   42451.0  49664443724  1169924
# 354  2020-05-23      0.0  43724.0  43724.0   43724.0  56895636380  1301245
# 355  2020-05-26  45035.0  45035.0  45035.0   45035.0  72796870785  1616451
# 356  2020-05-27  47286.0  47286.0  47286.0   47286.0  42068841048   889668
#
#      count    close
# 0        2   1000.0
# 1      150   2000.0
# 2       56   1950.0
# 3        8   1601.0
# 4       24   1890.0
# ..     ...      ...
# 352    762  41215.0
# 353    315  42451.0
# 354    257  43724.0
# 355    501  45035.0
# 356    422  47286.0
#
# [357 rows x 9 columns]

# %%
conn = sqlite3.connect('comments.db')

# %%
df.to_sql(name="comments", con=conn, if_exists="append", index=False)

# %%
import sqlite3

def symbols_table(pk):
    con = sqlite3.connect('/home/amir/venvs/new ones/finace_api/notebooks/tickers_data.db')
    cur = con.cursor()
    df = pd.read_sql_query("SELECT * from {}".format(pk), con)
    return df

# %%
df = symbols_table('آبین')
df
# Out:
#            date     open     high      low  adjClose         value    volume  \
# 0    2017-02-14   1000.0   1000.0   1000.0    1000.0         10000        10
# 1    2018-05-21   2000.0   2000.0   2000.0    2000.0    2725398000   1362699
# 2    2018-05-23   2000.0   2000.0   1950.0    1996.0     842461700    422047
# 3    2018-05-26   1995.0   1995.0   1601.0    1966.0      75575920     41560
# 4    2018-05-28   1890.0   1890.0   1890.0    1929.0     228225060    120754
# ..          ...      ...      ...      ...       ...           ...       ...
# 356  2020-05-27  47286.0  47286.0  47286.0   47286.0   42068841048    889668
# 357  2020-05-30  48704.0  48704.0  48704.0   48704.0  107546175936   2208159
# 358  2020-05-31  50165.0  50165.0  50165.0   50165.0  130192070705   2595277
# 359  2020-06-01  51669.0  51669.0  51669.0   51669.0  159364711791   3084339
# 360  2020-06-02  51669.0  52300.0  49086.0   49903.0  722835789144  14484818
#
#      count    close
# 0        2   1000.0
# 1      150   2000.0
# 2       56   1950.0
# 3        8   1601.0
# 4       24   1890.0
# ..     ...      ...
# 356    422  47286.0
# 357    216  48704.0
# 358    361  50165.0
# 359    777  51669.0
# 360  12075  49791.0
#
# [361 rows x 9 columns]

# %%
df_as_json = df.to_json(orient='records')
# Out:
# '[{"date":"2017-02-14","open":1000.0,"high":1000.0,"low":1000.0,"adjClose":1000.0,"value":10000,"volume":10,"count":2,"close":1000.0},{"date":"2018-05-21","open":2000.0,"high":2000.0,"low":2000.0,"adjClose":2000.0,"value":2725398000,"volume":1362699,"count":150,"close":2000.0},{"date":"2018-05-23","open":2000.0,"high":2000.0,"low":1950.0,"adjClose":1996.0,"value":842461700,"volume":422047,"count":56,"close":1950.0},{"date":"2018-05-26","open":1995.0,"high":1995.0,"low":1601.0,"adjClose":1966.0,"value":75575920,"volume":41560,"count":8,"close":1601.0},{"date":"2