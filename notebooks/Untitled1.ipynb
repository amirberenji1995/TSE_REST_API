# %%
import sqlite3

def list_of_symbols():
    con = sqlite3.connect('tickers_data.db')
    cursorObj = con.cursor()

    cursorObj.execute('SELECT name from sqlite_master where type= "table"')
    tables_list = cursorObj.fetchall()

    tables_list_str = []
    for item in tables_list:
        tables_list_str.append(''.join(item))

    return tables_list_str

# %%
tables_list_str = list_of_symbols()
tables_list_str
# Out:
# ['سیمرغ',
#  'وبرق',
#  'دجابر',
#  'وسنا',
#  'وحافظ',
#  'قلرست',
#  'غویتا',
#  'بفجر',
#  'فاراک',
#  'دتماد',
#  'ساینا',
#  'تپولا',
#  'بالبر',
#  'ختور',
#  'آرمان',
#  'پاسا',
#  'خپارس',
#  'فاذر',
#  'چدن',
#  'وسپه',
#  'ثشاهد',
#  'خموتور',
#  'تاصیکو',
#  'تکمبا',
#  'غگز',
#  'وسدید',
#  'تاپیکو',
#  'وهور',
#  'غبشهر',
#  'سبزوا',
#  'قجام',
#  'شصفها',
#  'وتوس',
#  'ولشرق',
#  'خفنر',
#  'وتجارت',
#  'سقاین',
#  'والبر',
#  'کفپارس',
#  'کشرق',
#  'ختراک',
#  'وثنو',
#  'ثجوان',
#  'کرمان',
#  'ولملت',
#  'کمرجان',
#  'وساپا',
#  'خدیزل',
#  'تمحرکه',
#  'وهنر',
#  'فخوز',
#  'سایرا',
#  'پارسان',
#  'نطرین',
#  'ورنا',
#  'فمراد',
#  'وبیمه',
#  'ددام',
#  'سفار',
#  'فلات',
#  'لسرما',
#  'شکلر',
#  'تاپکیش',
#  'فخاس',
#  'وپاسار',
#  'غمهرا',
#  'قشیر',
#  'شاوان',
#  'وارس',
#  'غپونه',
#  'حخزر',
#  'حکشتی',
#  'شفارا',
#  'لبوتان',
#  'مداران',
#  'غصینو',
#  'خراسان',
#  'چکارن',
#  'وتوسم',
#  'خکمک',
#  'هجرت',
#  'ومشان',
#  'وثخوز',
#  'شراز',
#  'افق',
#  'قزوین',
#  'کی بی سی',
#  'تکالا',
#  'وبملت',
#  'غشوکو',
#  'شپنا',
#  'آبین',
#  'ختوقا',
#  'پارتا',
#  'غشهداب',
#  'حفاری',
#  'افرا',
#  'قنیشا',
#  'غپینو',
#  'غشهد',
#  'وشمال',
#  'فجر',
#  'زشریف',
#  'ستران',
#  'درهآور',
#  'کسعدی',
#  'شتران',
#  'شپلی',
#  'فروس',
#  'ولصنم',
#  'خکرمان',
#  'سپرمی',
#  'شپاکسا',
#  'ثرود',
#  'سفاسی',
#  'دسینا',
#  'شسم',
#  'بپاس',
#  'میهن',
#  'سبجنو',
#  'ولراز',
#  'وآرین',
#  'نوری',
#  'شغدیر',
#  'وآیند',
#  'سدور',
#  'فاما',
#  'فرآور',
#  'شپاس',
#  'وآتوس',
#  'ثاژن',
#  'ولتجار',
#  'خاهن',
#  'وبوعلی',
#  'تپمپی',
#  'حاریا',
#  'قاروم',
#  'سصفها',
#  'شفارس',
#  'چافست',
#  'فسا',
#  'ساروم',
#  'دماوند',
#  'مارون',
#  'شبندر',
#  'کمینا',
#  'پشاهن',
#  'وآذر',
#  'رمپنا',
#  'چکاپا',
#  'بشهاب',
#  'وصندوق',
#  'حتوکا',
#  'دالبر',
#  'وآوا',
#  'کیمیا',
#  'کویر',
#  'ثشرق',
#  'ثغرب',
#  'شرنگی',
#  'ثزاگرس',
#  'شیران',
#  'ثاخت',
#  'ثاباد',
#  'آینده',
#  'وبشهر',
#  'پکویر',
#  'کماسه',
#  'ثنام',
#  'رتاپ',
#  'ثاصفا',
#  'فلامی',
#  'وغدیر',
#  'دارو',
#  'پارس',
#  'غفارس',
#  'بجهرم',
#  'لخانه',
#  'وصنا',
#  'کسرام',
#  'وکادو',
#  'گوهران',
#  'دهدشت',
#  'کلر',
#  'سخواف',
#  'دکیمی',
#  'دفارا',
#  'زماهان',
#  'شستان',
#  'وشهر',
#  'خوساز',
#  'قپیرا',
#  'سصوفی',
#  'ومعادن',
#  'سلار',
#  'دپارس',
#  'اپرداز',
#  'زقیام',
#  'سمازن',
#  'چکاوه',
#  'ولانا',
#  'بنو',
#  'سباقر',
#  'خاور',
#  'شیراز',
#  'بتک',
#  'غچین',
#  'فارس',
#  'نکالا',
#  'خصدرا',
#  'غیوان',
#  'کرماشا',
#  'ورازی',
#  'خمهر',
#  'شاراک',
#  'وثوق',
#  'ولساپا',
#  'وخارزم',
#  'دانا',
#  'خچرخش',
#  'سکرد',
#  'کابگن',
#  'فسرب',
#  'پتایر',
#  'دسبحان',
#  'پترول',
#  'جهرم',
#  'امید',
#  'دابور',
#  'ما',
#  'خودکفا',
#  'سهگمت',
#  'حپترو',
#  'شاملا',
#  'خرینگ',
#  'کلوند',
#  'کگل',
#  'سخوز',
#  'فایرا',
#  'لازما',
#  'ارفع',
#  'وسبحان',
#  'فماک',
#  'پاکشو',
#  'شگل',
#  'فروی',
#  'وسرمد',
#  'نبروج',
#  'تکنو',
#  'آسیا',
#  'زدشت',
#  'رکیش',
#  'سدبیر',
#  'فافزا',
#  'کفرآور',
#  'زمگسا',
#  'خبهمن',
#  'خعمرا',
#  'سجام',
#  'سغرب',
#  'شوینده',
#  'فملی',
#  'سیدکو',
#  'وتوکا',
#  'دلر',
#  'ممسنی',
#  'غدشت',
#  'بورس',
#  'ثالوند',
#  'داراب',
#  'کگهر',
#  'خاذین',
#  'غدام',
#  'بترانس',
#  'دتهران\u200c',
#  'قمرو',
#  'شخارک',
#  'فلوله',
#  'کپارس',
#  'ذوب',
#  'وبهمن',
#  'ثتوسا',
#  'قاسم',
#  'پدرخش',
#  'رنیک',
#  'ومهان',
#  'پسهند',
#  'ریشمک',
#  'بساما',
#  'سشمال',
#  'خلنت',
#  'غشاذر',
#  'کگاز',
#  'کقزوی',
#  'داوه',
#  'سدشت',
#  'واتی',
#  'کچاد',
#  'شتوکا',
#  'حسینا',
#  'شدوص',
#  'وتوصا',
#  'سشرق',
#  'بکاب',
#  'کورز',
#  'خودرو',
#  'وپست',
#  'خگستر',
#  'اخابر',
#  'قشرین',
#  'وپسا',
#  'فنرژی',
#  'پردیس',
#  'خشرق',
#  'حریل',
#  'دلقما',
#  'دشیمی',
#  'وجامی',
#  'حفارس',
#  'وحکمت',
#  'وصنعت',
#  'درازک',
#  'کحافظ',
#  'شکربن',
#  'وسین',
#  'فبیرا',
#  'چنوپا',
#  'کپشیر',
#  'حبندر',
#  'سرود',
#  'سخاش',
#  'شرانل',
#  'بکهنوج',
#  'ولبهمن',
#  'فجوش',
#  'فاسمین',
#  'غگلپا',
#  'کرازی',
#  'گپارس',
#  'غپآذر',
#  'کمنگنز',
#  'کهرام',
#  'وکار',
#  'داسوه',
#  'شتهران',
#  'مرقام',
#  'شسپا',
#  'وایرا',
#  'ونیکی',
#  'فاهواز',
#  'سبهان',
#  'فولاژ',
#  'برکت',
#  'کالا',
#  'ثعتما',
#  'سمتاز',
#  'های وب',
#  'شمواد',
#  'پکرمان',
#  'شفا',
#  'وآفری',
#  'بالاس',
#  'دتوزیع',
#  'کسرا',
#  'قشکر',
#  'خریخت',
#  'ثنظام',
#  'لکما',
#  'تکشا',
#  'واعتبار',
#  'قهکمت',
#  'بموتو',
#  'واحیا',
#  'تنوین',
#  'تفیرو',
#  'وبصادر',
#  'ثباغ',
#  'سنیر',
#  'پلاسک',
#  'شسینا',
#  'وسالت',
#  'وخاور',
#  'سهرمز',
#  'زشگزا',
#  'تبرک',
#  'زفکا',
#  'کوثر',
#  'تابا',
#  'دکوثر',
#  'شلرد',
#  'وملی',
#  'ساراب',
#  'تکنار',
#  'زبینا',
#  'دسانکو',
#  'لخزر',
#  'تشتاد',
#  'پلوله',
#  'شپدیس',
#  'ومعلم',
#  'اعتلا',
#  'سپ',
#  'نوین',
#  'همراه',
#  'اتکای',
#  'معیار ',
#  'نمرینو',
#  'غدیس',
#  'خزر',
#  'وامید',
#  'شگامرن',
#  'بمیلا',
#  'مادیرا',
#  'غگلستا',
#  'سفانو',
#  'فولای',
#  'ثمسکن',
#  'کنور',
#  'کبافق',
#  'فبستم',
#  'شبریز',
#  'دشیری',
#  'بخاور',
#  'دبالک',
#  'دفرا',
#  'وایران',
#  'فسدید',
#  'توسعه',
#  'قصفها',
#  'فنوال',
#  'وبانک',
#  'کدما',
#  'فجام',
#  'دروز',
#  'کیسون',
#  'فباهنر',
#  'گکیش',
#  'لابسا',
#  'غسالم',
#  'بایکا',
#  'ثپردیس',
#  'ولغدر',
#  'فنفت',
#  'بنیرو',
#  'بزاگرس',
#  'سیستم',
#  'قشهد',
#  'خمحور',
#  'هرمز',
#  'وگستر',
#  'کاذر',
#  'ثنور',
#  'غشصفا',
#  'تپکو',
#  'فن آوا',
#  'سکرما',
#  'کازرو',
#  'سیلام',
#  'ونیرو',
#  'دقاضی',
#  'شپارس',
#  'تیپیکو',
#  'شتولی',
#  'قرن',
#  'سخزر',
#  'خساپا',
#  'کاما',
#  'وتعاون',
#  'سرچشمه',
#  'خمحرکه',
#  'ساربیل',
#  'کفرا',
#  'وگردش',
#  'توریل',
#  'بهپاک',
#  'فسپا',
#  'شکبیر',
#  'خفناور',
#  'لپیام',
#  'لوتوس',
#  'دتولید',
#  'کترام',
#  'فسازان',
#  'فولاد',
#  'میدکو',
#  'چفیبر',
#  'کساپا',
#  'کصدف',
#  'کباده',
#  'وزمین',
#  'جم پیلن',
#  'نیرو',
#  'کتوکا',
#  'وملت',
#  'کاوه',
#  'بمپنا',
#  'حتاید',
#  'شجم',
#  'زگلدشت',
#  'ثامان',
#  'کپرور',
#  'فوکا',
#  'دکپسول',
#  'اوان',
#  'واحصا',
#  'غبهنوش',
#  'وپخش',
#  'شفن',
#  'سمگا',
#  'خکار',
#  'دعبید',
#  'کروی',
#  'ونفت',
#  'آپ',
#  'آریان',
#  'وتوشه',
#  'دامین',
#  'ثقزوی',
#  'وسینا',
#  'پلاست',
#  'ونوین',
#  'خفولا',
#  'کاسپین',
#  'دحاوی',
#  'دسبحا',
#  'رانفور',
#  'غنیلی',
#  'خنصیر',
#  'غگرجی',
#  'رتکو',
#  'شپترو',
#  'فپنتا',
#  'ثعمرا',
#  'زنجان',
#  'غبهار',
#  'سفارس',
#  'وملل',
#  'فزرین',
#  'پخش',
#  'کطبس',
#  'مبین',
#  'وپترو',
#  'زپارس',
#  'تلیسه',
#  'سپاها',
#  'شزنگ',
#  'ثفارس',
#  'مفاخر',
#  'دیران',
#  'زاگرس',
#  'غاذر',
#  'حپارسا',
#  'ودی',
#  'ساذری',
#  'سامان',
#  'سکارون',
#  'اتکام',
#  'قنقش',
#  'لپارس',
#  'شبصیر',
#  'خپویش',
#  'پرداخت',
#  'شنفت',
#  'البرز',
#  'پارسیان',
#  'کایتا',
#  'شبهرن',
#  'خزامیا',
#  'غالبر',
#  'جم',
#  'کهمدا',
#  'حآسا',
#  'تایرا',
#  'وساخت',
#  'قچار',
#  'بکام',
#  'وپارس',
#  'خکاوه',
#  'فالوم',
#  'ثتران',
#  'گکوثر',
#  'ثنوسا',
#  'کخاک']
